# %%
from tensorflow.keras.layers import Activation, Dense, Input, Conv2D, Flatten, Reshape, Conv2DTranspose, LeakyReLU, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
import numpy as np
import math
import matplotlib.pyplot as plt
import os

# %%
def gen_block(x, filters = 128, kernel_size = 5, strides = 2, padding = "same"):
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2DTranspose(filters = filters, kernel_size = kernel_size, strides = strides, padding = padding)(x)
    return x

def build_generator(inputs, image_size):
  image_resize = image_size // 4
  x = Dense(image_resize * image_resize * 128)(inputs)
  x = Reshape((image_resize, image_resize, 128))(x)
  x = gen_block(x = x, filters = 128, kernel_size = 5, strides = 2, padding = "same")
  x = gen_block(x = x, filters = 64, kernel_size = 5, strides = 2, padding = "same")
  x = gen_block(x = x, filters = 32, kernel_size = 5, strides = 1, padding = "same")
  x = gen_block(x = x, filters = 1, kernel_size = 5, strides = 1, padding = "same")
  x = Activation('sigmoid')(x)
  generator = Model(inputs, x, name = "generator")
  return generator


def disc_block(x, filters = 64, kernel_size = 5, strides = 2, padding = "same"):
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha = 0.2)(x)
  x = Conv2D(filters = filters, kernel_size = kernel_size, strides = strides, padding = padding)(x)
  return x

def build_discriminator(inputs):
   x = inputs
   x = LeakyReLU(alpha = 0.2)(x)
   x = Conv2D(filters = 32, kernel_size = 5, strides = 2, padding = "same")(x)
   x = disc_block(x = x, filters = 64, kernel_size = 5, strides = 2, padding = "same")
   x = disc_block(x = x, filters = 128, kernel_size = 5, strides = 2, padding = "same")
   x = disc_block(x = x, filters = 256, kernel_size = 5, strides = 1, padding = "same")
   x = Flatten()(x)
   x = Dense(1)(x)
   x = Activation("linear")(x)
   discriminator = Model(inputs, x, name = 'discriminator')
   return discriminator

# %%
(x_train, _), (_ , _) = mnist.load_data()
image_size = x_train.shape[1]
x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255

model_name = "wagan_mnist"
n_critic = 5
clip_value = 0.01
latent_size = 100 # latent vector of 100-dim
batch_size = 64
lr = 5e-5
train_steps = 3000 # one can train for more number of steps to get better quality
input_shape = (image_size, image_size, 1)

# loss function for the WGAN
def wassertian_loss(y_label, y_pred):
  return -K.mean(y_label * y_pred)

# discriminator model
inputs = Input(shape = input_shape, name = "discriminator_input")
discriminator = build_discriminator(inputs)
discriminator.compile(loss = wassertian_loss,
                      optimizer = RMSprop(learning_rate = lr),
                      metrics = ['accuracy'])
discriminator.summary()

# generator model
input_shape = (latent_size,)
inputs = Input(shape = input_shape, name = 'generator_input')
generator = build_generator(inputs, image_size)
generator.summary()

# adversarial model
discriminator.trainable = False
adversarial = Model(inputs, discriminator(generator(inputs)), name = model_name)
adversarial.compile(loss = wassertian_loss,
                    optimizer = RMSprop(learning_rate = lr),
                    metrics = ['accuracy'])
adversarial.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_input (Input  [(None, 28, 28, 1)]       0
#  Layer)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 28, 28, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        832
#
#  batch_normalization_7 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 14, 14, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          51264
#
#  batch_normalization_8 (Bat  (None, 7, 7, 64)          256
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 128)         204928
#
#  batch_normalization_9 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 256)         819456
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1)                 4097
#
#  activation_6 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1081473 (4.13 MB)
# Trainable params: 1081025 (4.12 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  generator_input (InputLaye  [(None, 100)]             0
#  r)
#
#  dense_3 (Dense)             (None, 6272)              633472
#
#  reshape_1 (Reshape)         (None, 7, 7, 128)         0
#
#  batch_normalization_10 (Ba  (None, 7, 7, 128)         512
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 7, 7, 128)         0
#
#  conv2d_transpose_4 (Conv2D  (None, 14, 14, 128)       409728
#  Transpose)
#
#  batch_normalization_11 (Ba  (None, 14, 14, 128)       512
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_5 (Conv2D  (None, 28, 28, 64)        204864
#  Transpose)
#
#  batch_normalization_12 (Ba  (None, 28, 28, 64)        256
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_6 (Conv2D  (None, 28, 28, 32)        51232
#  Transpose)
#
#  batch_normalization_13 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_7 (Conv2D  (None, 28, 28, 1)         801
#  Transpose)
#
#  activation_11 (Activation)  (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1301505 (4.96 MB)
# Trainable params: 1300801 (4.96 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________
# Model: "wagan_mnist"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  generator_input (InputLaye  [(None, 100)]             0
#  r)
#
#  generator (Functional)      (None, 28, 28, 1)         1301505
#
#  discriminator (Functional)  (None, 1)                 1081473
#
# =================================================================
# Total params: 2382978 (9.09 MB)
# Trainable params: 1300801 (4.96 MB)
# Non-trainable params: 1082177 (4.13 MB)
# _________________________________________________________________

# %%
def plot_images(generator,
                noise_input,
                noise_label=None,
                noise_codes=None,
                show=False,
                step=0,
                model_name="gan"):
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "%05d.png" % step)
    rows = int(math.sqrt(noise_input.shape[0]))
    if noise_label is not None:
        noise_input = [noise_input, noise_label]
        if noise_codes is not None:
            noise_input += noise_codes

    images = generator.predict(noise_input)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')

# %%
def train(models, x_train, params):

  generator, discriminator, adversarial = models
  batch_size, latent_size, n_critic, clip_value, train_steps, model_name = params
  save_interval = 500

  noise_input = np.random.uniform(-1.0, 1.0, size = [16, latent_size])
  train_size = x_train.shape[0]
  real_labels = np.ones((batch_size, 1))

  for i in range(train_steps):

    loss = 0
    acc = 0
    for _ in range(n_critic):

      rand_indexes = np.random.randint(0, train_size, size = batch_size)
      real_images = x_train[rand_indexes]
      noise = np.random.uniform(-1.0, 1.0, size = [batch_size, latent_size])
      fake_images = generator.predict(noise)
      real_loss, real_acc = discriminator.train_on_batch(real_images, real_labels)
      fake_loss, fake_acc = discriminator.train_on_batch(fake_images, -real_labels)

      # average
      loss += 0.5 * (real_loss + fake_loss)
      acc  += 0.5 * (real_acc + fake_acc)

      # clip weights
      for layer in discriminator.layers:
        weights = layer.get_weights()
        weights = [np.clip(weight, -clip_value, clip_value) for weight in weights]
        layer.set_weights(weights)

    loss /= n_critic
    acc /= n_critic
    log = f"{i}: [Discriminator Loss: {loss}, acc: {acc}]"
    print(log)

    noise = np.random.uniform(-1.0, 1.0, size = [batch_size, latent_size])
    loss, acc = adversarial.train_on_batch(noise, real_labels)
    log = f"{i}: [Adversarial Loss: {loss}, acc: {acc}]"
    print(log)

    if (i + 1) % save_interval == 0:
      plot_images(generator,
                  noise_input=noise_input,
                  show=False,
                  step=(i + 1),
                  model_name=model_name)

    generator.save(model_name + ".keras")

# %%
models = (generator, discriminator, adversarial)
params = (batch_size, latent_size, n_critic, clip_value, train_steps, model_name)
train(models, x_train, params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2286: [Discriminator Loss: -0.6408732652664184, acc: 0.0328125]
# 2286: [Adversarial Loss: -0.8805802464485168, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2287: [Discriminator Loss: -0.6365715071558953, acc: 0.028125]
# 2287: [Adversarial Loss: -0.8811934590339661, acc: 1.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2288: [Discriminator Loss: -0.625835494697094, acc: 0.03125]
# 2288: [Adversarial Loss: -0.8842266798019409, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2289: [Discriminator Loss: -0.6473916083574295, acc: 0.0359375]
# 2289: [Adversarial Loss: -0.8821587562561035, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2290: [Discriminator Loss: -0.6203341871500015, acc: 0.03125]
# 2290: [Adversarial Loss: -0.882789671421051, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2291: [Discriminator Loss: -0.6335417419672013, acc: 0.0328125]
# 2291: [Adversarial Loss: -0.884346067905426, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2292: [Discriminator Loss: -0.613951712846756, acc: 0.0296875]
# 2292: [Adversarial Loss: -0.8836376667022705, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2293: [Discriminator Loss: -0.6170762091875076, acc: 0.0296875]
# 2293: [Adversarial Loss: -0.8829010128974915, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2294: [Discriminator Loss: -0.6279604092240334, acc: 0.0234375]
# 2294: [Adversarial Loss: -0.8834280967712402, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2295: [Discriminator Loss: -0.6235668420791626, acc: 0.0234375]
# 2295: [Adversarial Loss: -0.8847955465316772, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2296: [Discriminator Loss: -0.6200098782777786, acc: 0.028125]
# 2296: [Adversarial Loss: -0.8862097859382629, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2297: [Discriminator Loss: -0.6325232714414597, acc: 0.0296875]
# 2297: [Adversarial Loss: -0.8851766586303711, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2298: [Discriminator Loss: -0.6285212486982346, acc: 0.04375]
# 2298: [Adversarial Loss: -0.8877362012863159, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2299: [Discriminator Loss: -0.6346653997898102, acc: 0.028125]
# 2299: [Adversarial Loss: -0.8865265846252441, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2300: [Discriminator Loss: -0.6180512428283691, acc: 0.0203125]
# 2300: [Adversarial Loss: -0.8860092759132385, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2301: [Discriminator Loss: -0.6312598794698715, acc: 0.034375]
# 2301: [Adversarial Loss: -0.8850786685943604, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2302: [Discriminator Loss: -0.625003308057785, acc: 0.025]
# 2302: [Adversarial Loss: -0.8848126530647278, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2303: [Discriminator Loss: -0.6299555420875549, acc: 0.0109375]
# 2303: [Adversarial Loss: -0.8828144073486328, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2304: [Discriminator Loss: -0.6126562088727951, acc: 0.0265625]
# 2304: [Adversarial Loss: -0.8842970132827759, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2305: [Discriminator Loss: -0.6206053510308266, acc: 0.021875]
# 2305: [Adversarial Loss: -0.886542558670044, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2306: [Discriminator Loss: -0.6166688591241837, acc: 0.01875]
# 2306: [Adversarial Loss: -0.8871704339981079, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2307: [Discriminator Loss: -0.628776341676712, acc: 0.0265625]
# 2307: [Adversarial Loss: -0.8859572410583496, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2308: [Discriminator Loss: -0.6332614332437515, acc: 0.0234375]
# 2308: [Adversarial Loss: -0.8862348794937134, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2309: [Discriminator Loss: -0.6336185783147812, acc: 0.021875]
# 2309: [Adversarial Loss: -0.885239839553833, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2310: [Discriminator Loss: -0.6368166327476501, acc: 0.0265625]
# 2310: [Adversarial Loss: -0.8857948184013367, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2311: [Discriminator Loss: -0.6390443414449691, acc: 0.0296875]
# 2311: [Adversarial Loss: -0.8823747038841248, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2312: [Discriminator Loss: -0.6224312722682953, acc: 0.0203125]
# 2312: [Adversarial Loss: -0.8824403285980225, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2313: [Discriminator Loss: -0.6266423419117928, acc: 0.0234375]
# 2313: [Adversarial Loss: -0.8821611404418945, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2314: [Discriminator Loss: -0.6248867928981781, acc: 0.025]
# 2314: [Adversarial Loss: -0.8835824728012085, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2315: [Discriminator Loss: -0.6298581689596177, acc: 0.0203125]
# 2315: [Adversarial Loss: -0.8844496607780457, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2316: [Discriminator Loss: -0.6296456068754196, acc: 0.0328125]
# 2316: [Adversarial Loss: -0.8837381601333618, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2317: [Discriminator Loss: -0.6396173298358917, acc: 0.025]
# 2317: [Adversarial Loss: -0.8850420713424683, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2318: [Discriminator Loss: -0.6355397582054139, acc: 0.025]
# 2318: [Adversarial Loss: -0.8842290639877319, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2319: [Discriminator Loss: -0.6122589915990829, acc: 0.0203125]
# 2319: [Adversarial Loss: -0.8854234218597412, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2320: [Discriminator Loss: -0.6340381130576134, acc: 0.03125]
# 2320: [Adversarial Loss: -0.8856999278068542, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2321: [Discriminator Loss: -0.6509560912847518, acc: 0.034375]
# 2321: [Adversarial Loss: -0.8826502561569214, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2322: [Discriminator Loss: -0.6237872019410133, acc: 0.028125]
# 2322: [Adversarial Loss: -0.8826584219932556, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2323: [Discriminator Loss: -0.6362661704421043, acc: 0.0171875]
# 2323: [Adversarial Loss: -0.8811724781990051, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2324: [Discriminator Loss: -0.6369466453790664, acc: 0.028125]
# 2324: [Adversarial Loss: -0.8826681971549988, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2325: [Discriminator Loss: -0.6354123964905739, acc: 0.034375]
# 2325: [Adversarial Loss: -0.8817178010940552, acc: 1.0]
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2326: [Discriminator Loss: -0.638736666738987, acc: 0.0359375]
# 2326: [Adversarial Loss: -0.8813369274139404, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2327: [Discriminator Loss: -0.6353497877717018, acc: 0.0234375]
# 2327: [Adversarial Loss: -0.8805563449859619, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2328: [Discriminator Loss: -0.6233413815498352, acc: 0.0328125]
# 2328: [Adversarial Loss: -0.8816065192222595, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2329: [Discriminator Loss: -0.6178950771689415, acc: 0.01875]
# 2329: [Adversarial Loss: -0.8840466141700745, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2330: [Discriminator Loss: -0.6109714120626449, acc: 0.03125]
# 2330: [Adversarial Loss: -0.8819212913513184, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2331: [Discriminator Loss: -0.632338210940361, acc: 0.0359375]
# 2331: [Adversarial Loss: -0.8817235231399536, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2332: [Discriminator Loss: -0.6258083403110504, acc: 0.0234375]
# 2332: [Adversarial Loss: -0.8811435699462891, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2333: [Discriminator Loss: -0.6099123448133469, acc: 0.021875]
# 2333: [Adversarial Loss: -0.8806270360946655, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2334: [Discriminator Loss: -0.6181077659130096, acc: 0.0203125]
# 2334: [Adversarial Loss: -0.8805255889892578, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2335: [Discriminator Loss: -0.6208086282014846, acc: 0.025]
# 2335: [Adversarial Loss: -0.8812087774276733, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2336: [Discriminator Loss: -0.6141015648841858, acc: 0.0203125]
# 2336: [Adversarial Loss: -0.8827708959579468, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2337: [Discriminator Loss: -0.6167265728116036, acc: 0.0171875]
# 2337: [Adversarial Loss: -0.8818105459213257, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2338: [Discriminator Loss: -0.6100688949227333, acc: 0.0140625]
# 2338: [Adversarial Loss: -0.8841050863265991, acc: 1.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2339: [Discriminator Loss: -0.6213433623313904, acc: 0.0203125]
# 2339: [Adversarial Loss: -0.8823787569999695, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2340: [Discriminator Loss: -0.6136887460947037, acc: 0.021875]
# 2340: [Adversarial Loss: -0.8827482461929321, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2341: [Discriminator Loss: -0.6179803103208542, acc: 0.0109375]
# 2341: [Adversarial Loss: -0.882431149482727, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2342: [Discriminator Loss: -0.6108454391360283, acc: 0.01875]
# 2342: [Adversarial Loss: -0.8811020255088806, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2343: [Discriminator Loss: -0.6254421591758728, acc: 0.028125]
# 2343: [Adversarial Loss: -0.8798450231552124, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2344: [Discriminator Loss: -0.6337760031223297, acc: 0.021875]
# 2344: [Adversarial Loss: -0.8779959082603455, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2345: [Discriminator Loss: -0.6406708747148514, acc: 0.0234375]
# 2345: [Adversarial Loss: -0.8770095109939575, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2346: [Discriminator Loss: -0.6288833394646645, acc: 0.025]
# 2346: [Adversarial Loss: -0.8770310878753662, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2347: [Discriminator Loss: -0.6074181526899338, acc: 0.025]
# 2347: [Adversarial Loss: -0.8779488801956177, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2348: [Discriminator Loss: -0.626576092839241, acc: 0.0140625]
# 2348: [Adversarial Loss: -0.8784815669059753, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2349: [Discriminator Loss: -0.6250440537929535, acc: 0.0265625]
# 2349: [Adversarial Loss: -0.8780612945556641, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2350: [Discriminator Loss: -0.6117422789335251, acc: 0.015625]
# 2350: [Adversarial Loss: -0.8778438568115234, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2351: [Discriminator Loss: -0.6160243794322013, acc: 0.0125]
# 2351: [Adversarial Loss: -0.8766291737556458, acc: 1.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2352: [Discriminator Loss: -0.6080660864710807, acc: 0.021875]
# 2352: [Adversarial Loss: -0.8773853778839111, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2353: [Discriminator Loss: -0.6149615377187729, acc: 0.0109375]
# 2353: [Adversarial Loss: -0.8772032260894775, acc: 1.0]
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2354: [Discriminator Loss: -0.6230578318238258, acc: 0.0171875]
# 2354: [Adversarial Loss: -0.8785792589187622, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2355: [Discriminator Loss: -0.6340517103672028, acc: 0.0296875]
# 2355: [Adversarial Loss: -0.8767154812812805, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2356: [Discriminator Loss: -0.5940720975399018, acc: 0.0265625]
# 2356: [Adversarial Loss: -0.8765944242477417, acc: 1.0]
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2357: [Discriminator Loss: -0.6217172712087631, acc: 0.0203125]
# 2357: [Adversarial Loss: -0.8768678903579712, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2358: [Discriminator Loss: -0.6038766101002693, acc: 0.01875]
# 2358: [Adversarial Loss: -0.8778858184814453, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2359: [Discriminator Loss: -0.6050883516669273, acc: 0.0203125]
# 2359: [Adversarial Loss: -0.8744338750839233, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2360: [Discriminator Loss: -0.5966882705688477, acc: 0.01875]
# 2360: [Adversarial Loss: -0.8776955008506775, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2361: [Discriminator Loss: -0.6122435897588729, acc: 0.0109375]
# 2361: [Adversarial Loss: -0.8779470920562744, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2362: [Discriminator Loss: -0.5993616819381714, acc: 0.015625]
# 2362: [Adversarial Loss: -0.8774556517601013, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2363: [Discriminator Loss: -0.614832480251789, acc: 0.0171875]
# 2363: [Adversarial Loss: -0.8778295516967773, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2364: [Discriminator Loss: -0.6070051580667496, acc: 0.0109375]
# 2364: [Adversarial Loss: -0.8775951862335205, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2365: [Discriminator Loss: -0.621952337026596, acc: 0.0171875]
# 2365: [Adversarial Loss: -0.8751872777938843, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2366: [Discriminator Loss: -0.5970136851072312, acc: 0.0140625]
# 2366: [Adversarial Loss: -0.8756660223007202, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2367: [Discriminator Loss: -0.6091358870267868, acc: 0.0125]
# 2367: [Adversarial Loss: -0.8731784820556641, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2368: [Discriminator Loss: -0.6124724105000496, acc: 0.015625]
# 2368: [Adversarial Loss: -0.8746265769004822, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2369: [Discriminator Loss: -0.6078525662422181, acc: 0.0140625]
# 2369: [Adversarial Loss: -0.8744735717773438, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2370: [Discriminator Loss: -0.6029890537261963, acc: 0.021875]
# 2370: [Adversarial Loss: -0.8759264349937439, acc: 1.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2371: [Discriminator Loss: -0.604215930402279, acc: 0.0234375]
# 2371: [Adversarial Loss: -0.8761961460113525, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2372: [Discriminator Loss: -0.5732909813523293, acc: 0.0140625]
# 2372: [Adversarial Loss: -0.8771789073944092, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2373: [Discriminator Loss: -0.5983332350850106, acc: 0.0296875]
# 2373: [Adversarial Loss: -0.8772392868995667, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2374: [Discriminator Loss: -0.5953514307737351, acc: 0.015625]
# 2374: [Adversarial Loss: -0.8773366212844849, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2375: [Discriminator Loss: -0.6083833783864975, acc: 0.021875]
# 2375: [Adversarial Loss: -0.8753134608268738, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2376: [Discriminator Loss: -0.5974838435649872, acc: 0.025]
# 2376: [Adversarial Loss: -0.8747850656509399, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2377: [Discriminator Loss: -0.607912340760231, acc: 0.0203125]
# 2377: [Adversarial Loss: -0.8756856322288513, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2378: [Discriminator Loss: -0.5733179733157158, acc: 0.021875]
# 2378: [Adversarial Loss: -0.8741999268531799, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2379: [Discriminator Loss: -0.61290924847126, acc: 0.0171875]
# 2379: [Adversarial Loss: -0.8753040432929993, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2380: [Discriminator Loss: -0.5694133788347244, acc: 0.0171875]
# 2380: [Adversarial Loss: -0.877183198928833, acc: 1.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2381: [Discriminator Loss: -0.5792413264513016, acc: 0.0125]
# 2381: [Adversarial Loss: -0.8772035837173462, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2382: [Discriminator Loss: -0.5725066021084786, acc: 0.0203125]
# 2382: [Adversarial Loss: -0.8784362077713013, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2383: [Discriminator Loss: -0.5917944580316543, acc: 0.0296875]
# 2383: [Adversarial Loss: -0.8782394528388977, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2384: [Discriminator Loss: -0.5763306856155396, acc: 0.028125]
# 2384: [Adversarial Loss: -0.8799618482589722, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2385: [Discriminator Loss: -0.5794988632202148, acc: 0.0203125]
# 2385: [Adversarial Loss: -0.8803167343139648, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2386: [Discriminator Loss: -0.5858296006917953, acc: 0.0125]
# 2386: [Adversarial Loss: -0.8791418075561523, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2387: [Discriminator Loss: -0.5764981120824814, acc: 0.01875]
# 2387: [Adversarial Loss: -0.8780471086502075, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2388: [Discriminator Loss: -0.5855174005031586, acc: 0.021875]
# 2388: [Adversarial Loss: -0.880394697189331, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2389: [Discriminator Loss: -0.5726454123854637, acc: 0.0171875]
# 2389: [Adversarial Loss: -0.8810133934020996, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2390: [Discriminator Loss: -0.5878301903605461, acc: 0.0234375]
# 2390: [Adversarial Loss: -0.8799484968185425, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2391: [Discriminator Loss: -0.5760248482227326, acc: 0.015625]
# 2391: [Adversarial Loss: -0.8798763751983643, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2392: [Discriminator Loss: -0.580081470310688, acc: 0.0171875]
# 2392: [Adversarial Loss: -0.8808484077453613, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2393: [Discriminator Loss: -0.577162367105484, acc: 0.015625]
# 2393: [Adversarial Loss: -0.8825138807296753, acc: 1.0]
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2394: [Discriminator Loss: -0.5984409675002098, acc: 0.015625]
# 2394: [Adversarial Loss: -0.8824261426925659, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2395: [Discriminator Loss: -0.5784873440861702, acc: 0.0125]
# 2395: [Adversarial Loss: -0.8807128667831421, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2396: [Discriminator Loss: -0.5811312347650528, acc: 0.0234375]
# 2396: [Adversarial Loss: -0.8800599575042725, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2397: [Discriminator Loss: -0.5860358268022537, acc: 0.0125]
# 2397: [Adversarial Loss: -0.8797670602798462, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2398: [Discriminator Loss: -0.5877376943826675, acc: 0.0234375]
# 2398: [Adversarial Loss: -0.877204179763794, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2399: [Discriminator Loss: -0.5835697397589683, acc: 0.0203125]
# 2399: [Adversarial Loss: -0.8788284659385681, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2400: [Discriminator Loss: -0.5802451431751251, acc: 0.0203125]
# 2400: [Adversarial Loss: -0.8777346014976501, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2401: [Discriminator Loss: -0.5822481706738472, acc: 0.0234375]
# 2401: [Adversarial Loss: -0.8787672519683838, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2402: [Discriminator Loss: -0.5764827787876129, acc: 0.03125]
# 2402: [Adversarial Loss: -0.8790521025657654, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2403: [Discriminator Loss: -0.560761672258377, acc: 0.01875]
# 2403: [Adversarial Loss: -0.8769290447235107, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2404: [Discriminator Loss: -0.5854348033666611, acc: 0.015625]
# 2404: [Adversarial Loss: -0.876816987991333, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2405: [Discriminator Loss: -0.583704462647438, acc: 0.0234375]
# 2405: [Adversarial Loss: -0.8771971464157104, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2406: [Discriminator Loss: -0.5808285668492317, acc: 0.0203125]
# 2406: [Adversarial Loss: -0.8766055703163147, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2407: [Discriminator Loss: -0.5768386974930764, acc: 0.028125]
# 2407: [Adversarial Loss: -0.8776673674583435, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2408: [Discriminator Loss: -0.5881665870547295, acc: 0.0171875]
# 2408: [Adversarial Loss: -0.8765109181404114, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2409: [Discriminator Loss: -0.5482446670532226, acc: 0.0234375]
# 2409: [Adversarial Loss: -0.8791669607162476, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2410: [Discriminator Loss: -0.5724150359630584, acc: 0.0140625]
# 2410: [Adversarial Loss: -0.8790771961212158, acc: 1.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2411: [Discriminator Loss: -0.5732112988829613, acc: 0.015625]
# 2411: [Adversarial Loss: -0.8786596059799194, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2412: [Discriminator Loss: -0.5796758353710174, acc: 0.015625]
# 2412: [Adversarial Loss: -0.8788869976997375, acc: 1.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2413: [Discriminator Loss: -0.544786873459816, acc: 0.0296875]
# 2413: [Adversarial Loss: -0.8814224004745483, acc: 1.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# ...
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2957: [Discriminator Loss: -0.10774339437484741, acc: 0.0]
# 2957: [Adversarial Loss: -0.11693395674228668, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2958: [Discriminator Loss: -0.10074153542518616, acc: 0.0]
# 2958: [Adversarial Loss: -0.14321255683898926, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2959: [Discriminator Loss: -0.07880299389362336, acc: 0.0015625]
# 2959: [Adversarial Loss: -0.14656496047973633, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2960: [Discriminator Loss: -0.07810290902853012, acc: 0.0]
# 2960: [Adversarial Loss: -0.15629202127456665, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2961: [Discriminator Loss: -0.06820942759513855, acc: 0.0]
# 2961: [Adversarial Loss: -0.15574166178703308, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2962: [Discriminator Loss: -0.06929478049278259, acc: 0.0]
# 2962: [Adversarial Loss: -0.16562321782112122, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2963: [Discriminator Loss: -0.06604330092668534, acc: 0.0]
# 2963: [Adversarial Loss: -0.16084882616996765, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2964: [Discriminator Loss: -0.07019869983196259, acc: 0.0]
# 2964: [Adversarial Loss: -0.1465248465538025, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2965: [Discriminator Loss: -0.07006770968437195, acc: 0.0]
# 2965: [Adversarial Loss: -0.1394132524728775, acc: 0.0]
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2966: [Discriminator Loss: -0.07570894211530685, acc: 0.0]
# 2966: [Adversarial Loss: -0.12651106715202332, acc: 0.0]
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2967: [Discriminator Loss: -0.08408559560775757, acc: 0.0]
# 2967: [Adversarial Loss: -0.1240394115447998, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2968: [Discriminator Loss: -0.08284369558095932, acc: 0.0]
# 2968: [Adversarial Loss: -0.10830347239971161, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2969: [Discriminator Loss: -0.09209345206618309, acc: 0.0]
# 2969: [Adversarial Loss: -0.10137317329645157, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2970: [Discriminator Loss: -0.09370237141847611, acc: 0.0]
# 2970: [Adversarial Loss: -0.10404988378286362, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2971: [Discriminator Loss: -0.09921728633344173, acc: 0.0]
# 2971: [Adversarial Loss: -0.08872146904468536, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2972: [Discriminator Loss: -0.09545271806418895, acc: 0.0]
# 2972: [Adversarial Loss: -0.0893237367272377, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2973: [Discriminator Loss: -0.10103901997208595, acc: 0.0]
# 2973: [Adversarial Loss: -0.09225934743881226, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2974: [Discriminator Loss: -0.09897137004882098, acc: 0.0]
# 2974: [Adversarial Loss: -0.08374164998531342, acc: 0.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2975: [Discriminator Loss: -0.09439214281737804, acc: 0.0]
# 2975: [Adversarial Loss: -0.08887279778718948, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2976: [Discriminator Loss: -0.09283918961882591, acc: 0.0]
# 2976: [Adversarial Loss: -0.09423860162496567, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2977: [Discriminator Loss: -0.08617529720067978, acc: 0.0]
# 2977: [Adversarial Loss: -0.10345249623060226, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2978: [Discriminator Loss: -0.08040365874767304, acc: 0.0]
# 2978: [Adversarial Loss: -0.12148530781269073, acc: 0.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2979: [Discriminator Loss: -0.07104437351226807, acc: 0.0]
# 2979: [Adversarial Loss: -0.12994152307510376, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2980: [Discriminator Loss: -0.06118037402629852, acc: 0.0]
# 2980: [Adversarial Loss: -0.14207985997200012, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2981: [Discriminator Loss: -0.05922367423772812, acc: 0.0]
# 2981: [Adversarial Loss: -0.14704038202762604, acc: 0.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2982: [Discriminator Loss: -0.0628170296549797, acc: 0.0]
# 2982: [Adversarial Loss: -0.14682775735855103, acc: 0.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2983: [Discriminator Loss: -0.06535153836011887, acc: 0.0]
# 2983: [Adversarial Loss: -0.14990179240703583, acc: 0.0]
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2984: [Discriminator Loss: -0.0662639707326889, acc: 0.0]
# 2984: [Adversarial Loss: -0.14792734384536743, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2985: [Discriminator Loss: -0.0634912297129631, acc: 0.0]
# 2985: [Adversarial Loss: -0.14682163298130035, acc: 0.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2986: [Discriminator Loss: -0.06844711750745773, acc: 0.0]
# 2986: [Adversarial Loss: -0.14431464672088623, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2987: [Discriminator Loss: -0.06856285631656647, acc: 0.0]
# 2987: [Adversarial Loss: -0.1395314633846283, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2988: [Discriminator Loss: -0.06846947073936463, acc: 0.0]
# 2988: [Adversarial Loss: -0.14212866127490997, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2989: [Discriminator Loss: -0.07635287940502167, acc: 0.0]
# 2989: [Adversarial Loss: -0.14397571980953217, acc: 0.0]
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2990: [Discriminator Loss: -0.07569640055298806, acc: 0.0]
# 2990: [Adversarial Loss: -0.13752219080924988, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2991: [Discriminator Loss: -0.08154270425438881, acc: 0.0]
# 2991: [Adversarial Loss: -0.13500168919563293, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2992: [Discriminator Loss: -0.08118298724293709, acc: 0.0]
# 2992: [Adversarial Loss: -0.1295330971479416, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2993: [Discriminator Loss: -0.0772174872457981, acc: 0.0]
# 2993: [Adversarial Loss: -0.137607142329216, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2994: [Discriminator Loss: -0.07054354250431061, acc: 0.0]
# 2994: [Adversarial Loss: -0.14130952954292297, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2995: [Discriminator Loss: -0.06028987169265747, acc: 0.0]
# 2995: [Adversarial Loss: -0.14769291877746582, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2996: [Discriminator Loss: -0.058403848111629485, acc: 0.0]
# 2996: [Adversarial Loss: -0.15242791175842285, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2997: [Discriminator Loss: -0.05007091611623764, acc: 0.0]
# 2997: [Adversarial Loss: -0.15792451798915863, acc: 0.0]
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2998: [Discriminator Loss: -0.04747993052005768, acc: 0.0]
# 2998: [Adversarial Loss: -0.16001388430595398, acc: 0.0]
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2999: [Discriminator Loss: -0.04318501204252243, acc: 0.0]
# 2999: [Adversarial Loss: -0.17116373777389526, acc: 0.0]
# 1/1 [==============================] - 0s 16ms/step
